# %%
import random

def wrongguess():
    if wrong == 1:
        print("          ___________________" + "\n") 
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |              ( ͡° ͜ʖ ͡°)" + "\n")
        print("          |" + "\n")               
        print("          |" + "\n")                  
        print("  ________|________" + "\n")        
        print("  |               |" + "\n")
        print("  |               |" + "\n")
        print("  |               |" + "\n")
        print("  |               |" + "\n")
        print("  |_______________|" + "\n")
    elif wrong == 2: 
        print("          ___________________" + "\n") 
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |              ( ͡° ͜ʖ ͡°)" + "\n")
        print("          |                  |" + "\n")               
        print("          |                  |" + "\n")                  
        print("  ________|________          |" + "\n")        
        print("  |               |          |" + "\n")
        print("  |               |          |" + "\n")
        print("  |               |" + "\n")
        print("  |               |" + "\n")
        print("  |_______________|" + "\n")
    elif wrong == 3:
        print("          ___________________" + "\n") 
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |          __  ( ͡° ͜ʖ ͡°)" + "\n")
        print("          |            \     |" + "\n")               
        print("          |             \____|" + "\n")                  
        print("  ________|________          |" + "\n")        
        print("  |               |          |" + "\n")
        print("  |               |          |" + "\n")
        print("  |               |" + "\n")
        print("  |               |" + "\n")
        print("  |_______________|" + "\n")
    elif wrong == 4:
        print("          ___________________" + "\n") 
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |          __  ( ͡° ͜ʖ ͡°)   __" + "\n")
        print("          |            \     |     /" + "\n")               
        print("          |             \____|____/" + "\n")                  
        print("  ________|________          |" + "\n")        
        print("  |               |          |" + "\n")
        print("  |               |          |" + "\n")
        print("  |               |" + "\n")
        print("  |               |" + "\n")
        print("  |_______________|" + "\n")
    elif wrong == 5:
        print("          ___________________" + "\n") 
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |          __  ( ͡° ͜ʖ ͡°)   __" + "\n")
        print("          |            \     |     /" + "\n")               
        print("          |             \____|____/" + "\n")                  
        print("  ________|________          |" + "\n")        
        print("  |               |          |" + "\n")
        print("  |               |          |" + "\n")
        print("  |               |         /" + "\n")
        print("  |               |        /" + "\n")
        print("  |_______________|      __|" + "\n")
    elif wrong == 6:
        print("          ___________________" + "\n") 
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |                 |" + "\n")
        print("          |          __  ( ͡° ͜ʖ ͡°)   __" + "\n")
        print("          |            \     |     /" + "\n")               
        print("          |             \____|____/" + "\n")                  
        print("  ________|________          |" + "\n")        
        print("  |               |          |" + "\n")
        print("  |               |          |" + "\n")
        print("  |               |         / \ \n")
        print("  |               |        /   \ \n")
        print("  |_______________|      __|   |__" + "\n")
        print("GAME OVER.")

wordlist = ["house", "chairs", "broken", "bodywash", "clothing",
                 "computer", "python", "life", "games",
                 "shirt", "pants", "friends", "Jake", "Jay",
                 "music", "jumbo", "knives", "bathing", "dorms"]

word = random.choice(wordlist).lower()

wrong = 0
num = len(word)
final_word = ["_", "_"]
x = 0
while x < (num - 2):
    final_word.append("_")
    x = x + 1
#print (word)
print(final_word)
try:
    while wrong < 6:
        guess = input("Enter a letter A-Z, 'Word' to guess the whole word, or 'Quit' to stop playing, When you guess all the letters you may type 'word' and enter the entire phrase: \n").lower()
        
        if guess == 'word':
            guess = input("What is the whole word? ")
            if guess == word:
                print("CONGRATS! YOU WIN!")
                break
            elif guess != word:
                wrong += 1
                wrongguess()
                print("\n")
        
        elif guess == "quit":
            break
        
        elif len(guess) > 1:
            print("That is more than one letter.")
            print("\n")
            continue        
            
        elif guess in word:
            place = word.find(guess)
            print(place)
            final_word[place] = guess
            print(final_word)
            print("\n")
            
        else:
            wrong = wrong + 1
            wrongguess()
            if wrong > 6:
                break
            
except:
    print("Put in a letter or word.")
# Out:
# ['_', '_', '_', '_']
# 1
# ['_', 'a', '_', '_']
#
#
#           ___________________
#
#           |                 |
#
#           |                 |
#
#           |                 |
#
#           |              ( ͡° ͜ʖ ͡°)
#
#           |
#
#           |
#
#   ________|________
#
#   |               |
#
#   |               |
#
#   |               |
#
#   |               |
#
#   |_______________|
#
# 2
# ['_', 'a', 'k', '_']
#
#
# 0
# ['j', 'a', 'k', '_']
#
#
# 3
# ['j', 'a', 'k', 'e']
#
#
# CONGRATS! YOU WIN!
