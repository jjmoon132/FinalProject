# %%
try:
    word = input("Enter the word for hangman: ")
except:
    print("Put in a word.")
    
wrong = 0
num = len(word)
final_word = "_" * num
print(final_word)
final_word[0] = "h"

try:
    while wrong < 6:
        guess = input("Enter the letter or word you want to guess: ")
        if guess in word:
            print("hi")
                
        else:
            wrong = wrong + 1
            if wrong == 1:
                print("          ___________________" + "\n") 
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |              ( ͡° ͜ʖ ͡°)" + "\n")
                print("          |" + "\n")               
                print("          |" + "\n")                  
                print("  ________|________" + "\n")        
                print("  |               |" + "\n")
                print("  |               |" + "\n")
                print("  |               |" + "\n")
                print("  |               |" + "\n")
                print("  |_______________|" + "\n")
            elif wrong == 2: 
                print("          ___________________" + "\n") 
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |              ( ͡° ͜ʖ ͡°)" + "\n")
                print("          |                  |" + "\n")               
                print("          |                  |" + "\n")                  
                print("  ________|________          |" + "\n")        
                print("  |               |          |" + "\n")
                print("  |               |          |" + "\n")
                print("  |               |" + "\n")
                print("  |               |" + "\n")
                print("  |_______________|" + "\n")
            elif wrong == 3:
                print("          ___________________" + "\n") 
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |          __  ( ͡° ͜ʖ ͡°)" + "\n")
                print("          |            \     |" + "\n")               
                print("          |             \____|" + "\n")                  
                print("  ________|________          |" + "\n")        
                print("  |               |          |" + "\n")
                print("  |               |          |" + "\n")
                print("  |               |" + "\n")
                print("  |               |" + "\n")
                print("  |_______________|" + "\n")
            elif wrong == 4:
                print("          ___________________" + "\n") 
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |          __  ( ͡° ͜ʖ ͡°)   __" + "\n")
                print("          |            \     |     /" + "\n")               
                print("          |             \____|____/" + "\n")                  
                print("  ________|________          |" + "\n")        
                print("  |               |          |" + "\n")
                print("  |               |          |" + "\n")
                print("  |               |" + "\n")
                print("  |               |" + "\n")
                print("  |_______________|" + "\n")
            elif wrong == 5:
                print("          ___________________" + "\n") 
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |          __  ( ͡° ͜ʖ ͡°)   __" + "\n")
                print("          |            \     |     /" + "\n")               
                print("          |             \____|____/" + "\n")                  
                print("  ________|________          |" + "\n")        
                print("  |               |          |" + "\n")
                print("  |               |          |" + "\n")
                print("  |               |         /" + "\n")
                print("  |               |        /" + "\n")
                print("  |_______________|      __|" + "\n")
            elif wrong == 6:
                print("          ___________________" + "\n") 
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |                 |" + "\n")
                print("          |          __  ( ͡° ͜ʖ ͡°)   __" + "\n")
                print("          |            \     |     /" + "\n")               
                print("          |             \____|____/" + "\n")                  
                print("  ________|________          |" + "\n")        
                print("  |               |          |" + "\n")
                print("  |               |          |" + "\n")
                print("  |               |         / \ \n")
                print("  |               |        /   \ \n")
                print("  |_______________|      __|   |__" + "\n")
                print("GAME OVER.")
                break
            
except:
    print("Put in a letter or word.")
# Out:
# _____
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-47bb9bd5e88d> in <module>()
#       8 final_word = "_" * num
#       9 print(final_word)
# ---> 10 final_word[0] = "-h"
#      11
#      12 try:
#
# TypeError: 'str' object does not support item assignment
